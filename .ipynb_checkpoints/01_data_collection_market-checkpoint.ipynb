# %%
# !pip install yfinance pandas matplotlib seaborn

import yfinance as yf
import pandas as pd
import os
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
# Out:
# Requirement already satisfied: yfinance in c:\users\frang\anaconda3\lib\site-packages (0.2.65)
# Requirement already satisfied: pandas in c:\users\frang\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\frang\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\frang\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\frang\anaconda3\lib\site-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in c:\users\frang\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\frang\anaconda3\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\frang\anaconda3\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in c:\users\frang\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\frang\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\frang\anaconda3\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\frang\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\frang\anaconda3\lib\site-packages (from yfinance) (0.12.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\frang\anaconda3\lib\site-packages (from yfinance) (5.29.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\frang\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\frang\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\frang\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\frang\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\frang\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\frang\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\frang\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\frang\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\frang\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\frang\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\frang\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\frang\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\frang\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.4.26)
# Requirement already satisfied: pycparser in c:\users\frang\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\frang\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\frang\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\frang\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\frang\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.3.0)

# %%
os.makedirs("../data/raw", exist_ok=True)

# %%
# Example: Spanish IBEX35 and US S&P500
tickers = {
    "IBEX35": "^IBEX",
    "S&P500": "^GSPC",
    "NASDAQ": "^IXIC",
    "AAPL": "AAPL",
    "MSFT": "MSFT"
}

start_date = "2015-01-01"
end_date = datetime.today().strftime('%Y-%m-%d')

# %%
# Download and store data
market_data = {}

for name, ticker in tickers.items():
    print(f"Downloading {name} data...")
    df = yf.download(ticker, start=start_date, end=end_date)
    df.reset_index(inplace=True)
    df['Ticker'] = name
    market_data[name] = df
    df.to_csv(f"../data/raw/{name}_market.csv", index=False)

print("Market data saved in ../data/raw/")
# Out:
# Downloading IBEX35 data...
# C:\Users\frang\AppData\Local\Temp\ipykernel_47504\1397364326.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\frang\AppData\Local\Temp\ipykernel_47504\1397364326.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# Downloading S&P500 data...
# [*********************100%***********************]  1 of 1 completed
# C:\Users\frang\AppData\Local\Temp\ipykernel_47504\1397364326.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# Downloading NASDAQ data...
# [*********************100%***********************]  1 of 1 completed
# C:\Users\frang\AppData\Local\Temp\ipykernel_47504\1397364326.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# Downloading AAPL data...
# [*********************100%***********************]  1 of 1 completed
# C:\Users\frang\AppData\Local\Temp\ipykernel_47504\1397364326.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# Downloading MSFT data...
# [*********************100%***********************]  1 of 1 completed
# Market data saved in ../data/raw/

# %%
# Quick visualization
plt.figure(figsize=(12,6))
for name, df in market_data.items():
    plt.plot(df['Date'], df['Close'], label=name)
plt.legend()
plt.title("Market Closing Prices")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.show()
