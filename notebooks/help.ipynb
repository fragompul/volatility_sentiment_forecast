# %%
import os

# Diccionario con los nombres de carpetas y sus rutas relativas desde 'notebooks'
folders = {
    'notebooks': '.',
    'models': '../models',
    'predictions': '../predictions',
    'data/raw': '../data/raw',
    'data/processed': '../data/processed'
}

# Recorremos cada carpeta y listamos los archivos que contiene
folder_files = {}
for name, path in folders.items():
    try:
        files = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
        folder_files[name] = files
    except FileNotFoundError:
        folder_files[name] = ['[Ruta no encontrada]']

# Imprime el resultado (opcional)
for folder, files in folder_files.items():
    print(f"{folder}:")
    for file in files:
        print(f"  - {file}")
    print()

# Si quieres usar el diccionario en tu código
# puedes accederlo como 'folder_files'
# Out:
# notebooks:
#   - 01_data_collection_market.ipynb
#   - 02_data_collection_tweets.ipynb
#   - 03_data_collection_news.ipynb
#   - 04_data_cleaning_market.ipynb
#   - 05_data_cleaning_tweets.ipynb
#   - 06_data_cleaning_news.ipynb
#   - 07_future_engineering_market.ipynb
#   - 08_future_engineering_sentiment.ipynb
#   - 09_sentiment_analysis_transformers.ipynb
#   - 10_model_volatility_timeseries.ipynb
#   - 11_model_volatility_transformers.ipynb
#   - 12_lstm_evaluation.ipynb
#   - 13_tft_evaluation.ipynb
#   - 14_model_comparison.ipynb
#   - 15_error_analysis_metrics.ipynb
#   - 16_temporal_error_analysis.ipynb
#   - Untitled.ipynb
#
# models:
#   - predictions_AAPL.csv
#   - predictions_IBEX35.csv
#   - predictions_MSFT.csv
#   - predictions_NASDAQ.csv
#   - predictions_S&P500.csv
#   - predictions_TFT_AAPL.csv
#   - predictions_TFT_IBEX35.csv
#   - predictions_TFT_MSFT.csv
#   - predictions_TFT_NASDAQ.csv
#   - predictions_TFT_S&P500.csv
#   - scaler_X_AAPL.pkl
# ...
