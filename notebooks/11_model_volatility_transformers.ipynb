# %%
import importlib.metadata
print(importlib.metadata.version("scikit-base"))
# Out:
# 0.12.4

# %%
from importlib.metadata import distributions

for dist in distributions():
    try:
        name = dist.metadata['Name']
    except KeyError:
        print("Paquete con metadatos incompletos:", dist)
# Out:
# C:\Users\frang\AppData\Local\Temp\ipykernel_38000\2716593324.py:5: DeprecationWarning: Implicit None on return values is deprecated and will raise KeyErrors.
#   name = dist.metadata['Name']

# %%
# !pip cache purge
# !pip install --force-reinstall pytorch-forecasting scikit-base
# Out:
# Files removed: 10 (1.9 MB)
# Collecting pytorch-forecasting
#   Downloading pytorch_forecasting-1.4.0-py3-none-any.whl.metadata (14 kB)
# Collecting scikit-base
#   Downloading scikit_base-0.12.4-py3-none-any.whl.metadata (8.8 kB)
# Collecting numpy<=3.0.0 (from pytorch-forecasting)
#   Downloading numpy-2.3.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting torch!=2.0.1,<3.0.0,>=2.0.0 (from pytorch-forecasting)
#   Downloading torch-2.7.1-cp313-cp313-win_amd64.whl.metadata (28 kB)
# Collecting lightning<3.0.0,>=2.0.0 (from pytorch-forecasting)
#   Downloading lightning-2.5.2-py3-none-any.whl.metadata (38 kB)
# Collecting scipy<2.0,>=1.8 (from pytorch-forecasting)
#   Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting pandas<3.0.0,>=1.3.0 (from pytorch-forecasting)
#   Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting scikit-learn<2.0,>=1.2 (from pytorch-forecasting)
#   Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting PyYAML<8.0,>=5.4 (from lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading PyYAML-6.0.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
# Collecting fsspec<2027.0,>=2022.5.0 (from fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading lightning_utilities-0.15.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting packaging<27.0,>=20.0 (from lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading torchmetrics-1.8.0-py3-none-any.whl.metadata (21 kB)
# Collecting tqdm<6.0,>=4.57.0 (from lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting typing-extensions<6.0,>=4.4.0 (from lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pytorch-lightning (from lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading pytorch_lightning-2.5.2-py3-none-any.whl.metadata (21 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl.metadata (7.9 kB)
# Collecting setuptools (from lightning-utilities<2.0,>=0.10.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting python-dateutil>=2.8.2 (from pandas<3.0.0,>=1.3.0->pytorch-forecasting)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas<3.0.0,>=1.3.0->pytorch-forecasting)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0.0,>=1.3.0->pytorch-forecasting)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting joblib>=1.2.0 (from scikit-learn<2.0,>=1.2->pytorch-forecasting)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<2.0,>=1.2->pytorch-forecasting)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting sympy>=1.13.3 (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting colorama (from tqdm<6.0,>=4.57.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading frozenlist-1.7.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading multidict-6.6.3-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading propcache-0.3.2-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading yarl-1.20.1-cp313-cp313-win_amd64.whl.metadata (76 kB)
# Collecting idna>=2.0 (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.3.0->pytorch-forecasting)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl.metadata (4.1 kB)
# Downloading pytorch_forecasting-1.4.0-py3-none-any.whl (260 kB)
# Downloading lightning-2.5.2-py3-none-any.whl (821 kB)
#    ---------------------------------------- 0.0/821.1 kB ? eta -:--:--
#    ---------------------------------------- 821.1/821.1 kB 9.5 MB/s  0:00:00
# Downloading fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Downloading lightning_utilities-0.15.0-py3-none-any.whl (29 kB)
# Downloading numpy-2.3.2-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------- ----------------------------- 3.4/12.8 MB 16.8 MB/s eta 0:00:01
#    --------------------------- ------------ 8.9/12.8 MB 21.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 22.9 MB/s  0:00:00
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ----------------------------- ---------- 8.1/11.0 MB 39.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 32.8 MB/s  0:00:00
# Downloading PyYAML-6.0.2-cp313-cp313-win_amd64.whl (156 kB)
# Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------  8.7/8.7 MB 44.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 40.0 MB/s  0:00:00
# Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------- ----------------------------- 9.7/38.5 MB 47.2 MB/s eta 0:00:01
#    ------------------- -------------------- 18.4/38.5 MB 43.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.3/38.5 MB 42.9 MB/s eta 0:00:01
#    ------------------------------------- -- 36.2/38.5 MB 43.0 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 43.2 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 35.4 MB/s  0:00:01
# Downloading torch-2.7.1-cp313-cp313-win_amd64.whl (216.1 MB)
#    ---------------------------------------- 0.0/216.1 MB ? eta -:--:--
#    - -------------------------------------- 9.7/216.1 MB 46.4 MB/s eta 0:00:05
#    --- ------------------------------------ 19.1/216.1 MB 45.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 29.4/216.1 MB 45.8 MB/s eta 0:00:05
#    ------- -------------------------------- 40.6/216.1 MB 47.6 MB/s eta 0:00:04
#    --------- ------------------------------ 52.4/216.1 MB 49.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 62.9/216.1 MB 49.3 MB/s eta 0:00:04
#    ------------- -------------------------- 74.4/216.1 MB 49.8 MB/s eta 0:00:03
#    --------------- ------------------------ 85.2/216.1 MB 49.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 96.5/216.1 MB 50.1 MB/s eta 0:00:03
#    ------------------- ------------------- 106.7/216.1 MB 49.8 MB/s eta 0:00:03
#    -------------------- ------------------ 115.3/216.1 MB 49.1 MB/s eta 0:00:03
#    ---------------------- ---------------- 125.6/216.1 MB 49.1 MB/s eta 0:00:02
#    ------------------------ -------------- 135.5/216.1 MB 48.8 MB/s eta 0:00:02
#    -------------------------- ------------ 145.0/216.1 MB 48.5 MB/s eta 0:00:02
#    --------------------------- ----------- 154.7/216.1 MB 48.3 MB/s eta 0:00:02
#    ----------------------------- --------- 164.1/216.1 MB 48.0 MB/s eta 0:00:02
#    ------------------------------- ------- 174.9/216.1 MB 48.1 MB/s eta 0:00:01
#    --------------------------------- ----- 183.5/216.1 MB 47.7 MB/s eta 0:00:01
#    ---------------------------------- ---- 192.7/216.1 MB 47.4 MB/s eta 0:00:01
#    ------------------------------------ -- 202.1/216.1 MB 47.2 MB/s eta 0:00:01
#    --------------------------------------  211.3/216.1 MB 47.0 MB/s eta 0:00:01
#    --------------------------------------  216.0/216.1 MB 46.9 MB/s eta 0:00:01
#    --------------------------------------  216.0/216.1 MB 46.9 MB/s eta 0:00:01
#    ---------------------------------------- 216.1/216.1 MB 43.7 MB/s  0:00:04
# Downloading torchmetrics-1.8.0-py3-none-any.whl (981 kB)
#    ---------------------------------------- 0.0/981.9 kB ? eta -:--:--
#    ---------------------------------------- 981.9/981.9 kB 39.7 MB/s  0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Downloading scikit_base-0.12.4-py3-none-any.whl (145 kB)
# Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl (449 kB)
# Downloading multidict-6.6.3-cp313-cp313-win_amd64.whl (45 kB)
# Downloading yarl-1.20.1-cp313-cp313-win_amd64.whl (86 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.7.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading propcache-0.3.2-cp313-cp313-win_amd64.whl (40 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 41.7 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 27.3 MB/s  0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl (15 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 33.9 MB/s  0:00:00
# Downloading pytorch_lightning-2.5.2-py3-none-any.whl (825 kB)
#    ---------------------------------------- 0.0/825.4 kB ? eta -:--:--
#    ---------------------------------------- 825.4/825.4 kB 32.0 MB/s  0:00:00
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 42.5 MB/s  0:00:00
# Installing collected packages: pytz, mpmath, tzdata, typing-extensions, threadpoolctl, sympy, six, setuptools, scikit-base, PyYAML, propcache, packaging, numpy, networkx, multidict, MarkupSafe, joblib, idna, fsspec, frozenlist, filelock, colorama, attrs, aiohappyeyeballs, yarl, tqdm, scipy, python-dateutil, lightning-utilities, jinja2, aiosignal, torch, scikit-learn, pandas, aiohttp, torchmetrics, pytorch-lightning, lightning, pytorch-forecasting
#
#   Attempting uninstall: pytz
#
#     Found existing installation: pytz 2024.1
#
#    ----------------------------------------  0/39 [pytz]
#     Uninstalling pytz-2024.1:
#    ----------------------------------------  0/39 [pytz]
#       Successfully uninstalled pytz-2024.1
#    ----------------------------------------  0/39 [pytz]
#    ----------------------------------------  0/39 [pytz]
#    ----------------------------------------  0/39 [pytz]
#    ----------------------------------------  0/39 [pytz]
#    ----------------------------------------  0/39 [pytz]
#    ----------------------------------------  0/39 [pytz]
#    ----------------------------------------  0/39 [pytz]
#    ----------------------------------------  0/39 [pytz]
#   Attempting uninstall: mpmath
#    ----------------------------------------  0/39 [pytz]
#     Found existing installation: mpmath 1.3.0
#    ----------------------------------------  0/39 [pytz]
#    - --------------------------------------  1/39 [mpmath]
#     Uninstalling mpmath-1.3.0:
#    - --------------------------------------  1/39 [mpmath]
#       Successfully uninstalled mpmath-1.3.0
#    - --------------------------------------  1/39 [mpmath]
#    - --------------------------------------  1/39 [mpmath]
#    - --------------------------------------  1/39 [mpmath]
#    - --------------------------------------  1/39 [mpmath]
#    - --------------------------------------  1/39 [mpmath]
#    - --------------------------------------  1/39 [mpmath]
#    - --------------------------------------  1/39 [mpmath]
#    - --------------------------------------  1/39 [mpmath]
#    - --------------------------------------  1/39 [mpmath]
#   Attempting uninstall: tzdata
#    - --------------------------------------  1/39 [mpmath]
#     Found existing installation: tzdata 2025.2
#    - --------------------------------------  1/39 [mpmath]
#    -- -------------------------------------  2/39 [tzdata]
#    -- -------------------------------------  2/39 [tzdata]
#    -- -------------------------------------  2/39 [tzdata]
#     Uninstalling tzdata-2025.2:
#    -- -------------------------------------  2/39 [tzdata]
#       Successfully uninstalled tzdata-2025.2
#    -- -------------------------------------  2/39 [tzdata]
#    -- -------------------------------------  2/39 [tzdata]
#    -- -------------------------------------  2/39 [tzdata]
#    -- -------------------------------------  2/39 [tzdata]
#    -- -------------------------------------  2/39 [tzdata]
#    -- -------------------------------------  2/39 [tzdata]
#    -- -------------------------------------  2/39 [tzdata]
#    -- -------------------------------------  2/39 [tzdata]
#    -- -------------------------------------  2/39 [tzdata]
#   Attempting uninstall: typing-extensions
#    -- -------------------------------------  2/39 [tzdata]
#     Found existing installation: typing_extensions 4.12.2
#    -- -------------------------------------  2/39 [tzdata]
#     Uninstalling typing_extensions-4.12.2:
#    -- -------------------------------------  2/39 [tzdata]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    --- ------------------------------------  3/39 [typing-extensions]
#    --- ------------------------------------  3/39 [typing-extensions]
#   Attempting uninstall: threadpoolctl
#    --- ------------------------------------  3/39 [typing-extensions]
#     Found existing installation: threadpoolctl 3.5.0
#    --- ------------------------------------  3/39 [typing-extensions]
#     Uninstalling threadpoolctl-3.5.0:
#    --- ------------------------------------  3/39 [typing-extensions]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#       Successfully uninstalled threadpoolctl-3.5.0
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ---- -----------------------------------  4/39 [threadpoolctl]
#   Attempting uninstall: sympy
#    ---- -----------------------------------  4/39 [threadpoolctl]
#     Found existing installation: sympy 1.13.3
#    ---- -----------------------------------  4/39 [threadpoolctl]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#     Uninstalling sympy-1.13.3:
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#       Successfully uninstalled sympy-1.13.3
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#    ----- ----------------------------------  5/39 [sympy]
#   Attempting uninstall: six
#    ----- ----------------------------------  5/39 [sympy]
#     Found existing installation: six 1.17.0
#    ----- ----------------------------------  5/39 [sympy]
#     Uninstalling six-1.17.0:
#    ----- ----------------------------------  5/39 [sympy]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#       Successfully uninstalled six-1.17.0
#    ------ ---------------------------------  6/39 [six]
#    ------ ---------------------------------  6/39 [six]
#   Attempting uninstall: setuptools
#    ------ ---------------------------------  6/39 [six]
#     Found existing installation: setuptools 72.1.0
#    ------ ---------------------------------  6/39 [six]
#     Uninstalling setuptools-72.1.0:
#    ------ ---------------------------------  6/39 [six]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#       Successfully uninstalled setuptools-72.1.0
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#    ------- --------------------------------  7/39 [setuptools]
#   Attempting uninstall: scikit-base
#    ------- --------------------------------  7/39 [setuptools]
#    -------- -------------------------------  8/39 [scikit-base]
#     Found existing installation: scikit-base 0.12.4
#    -------- -------------------------------  8/39 [scikit-base]
#     Uninstalling scikit-base-0.12.4:
#    -------- -------------------------------  8/39 [scikit-base]
#       Successfully uninstalled scikit-base-0.12.4
#    -------- -------------------------------  8/39 [scikit-base]
#    -------- -------------------------------  8/39 [scikit-base]
#    -------- -------------------------------  8/39 [scikit-base]
#    -------- -------------------------------  8/39 [scikit-base]
#   Attempting uninstall: PyYAML
#    -------- -------------------------------  8/39 [scikit-base]
#     Found existing installation: PyYAML 6.0.2
#    -------- -------------------------------  8/39 [scikit-base]
#     Uninstalling PyYAML-6.0.2:
#    -------- -------------------------------  8/39 [scikit-base]
#       Successfully uninstalled PyYAML-6.0.2
#    -------- -------------------------------  8/39 [scikit-base]
#    --------- ------------------------------  9/39 [PyYAML]
#    --------- ------------------------------  9/39 [PyYAML]
#   Attempting uninstall: propcache
#    --------- ------------------------------  9/39 [PyYAML]
#     Found existing installation: propcache 0.3.1
#    --------- ------------------------------  9/39 [PyYAML]
#     Uninstalling propcache-0.3.1:
#    --------- ------------------------------  9/39 [PyYAML]
#       Successfully uninstalled propcache-0.3.1
#    --------- ------------------------------  9/39 [PyYAML]
#   Attempting uninstall: packaging
#    --------- ------------------------------  9/39 [PyYAML]
#    ----------- ---------------------------- 11/39 [packaging]
#     Found existing installation: packaging 24.2
#    ----------- ---------------------------- 11/39 [packaging]
#     Uninstalling packaging-24.2:
#    ----------- ---------------------------- 11/39 [packaging]
#       Successfully uninstalled packaging-24.2
#    ----------- ---------------------------- 11/39 [packaging]
#    ----------- ---------------------------- 11/39 [packaging]
#   Attempting uninstall: numpy
#    ----------- ---------------------------- 11/39 [packaging]
#     Found existing installation: numpy 2.1.3
#    ----------- ---------------------------- 11/39 [packaging]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#     Uninstalling numpy-2.1.3:
#    ------------ --------------------------- 12/39 [numpy]
#       Successfully uninstalled numpy-2.1.3
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#    ------------ --------------------------- 12/39 [numpy]
#   Attempting uninstall: networkx
#    ------------ --------------------------- 12/39 [numpy]
#     Found existing installation: networkx 3.4.2
#    ------------ --------------------------- 12/39 [numpy]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#     Uninstalling networkx-3.4.2:
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#       Successfully uninstalled networkx-3.4.2
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
#    ------------- -------------------------- 13/39 [networkx]
# ...
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#    -------------------------------- ------- 32/39 [scikit-learn]
#   Attempting uninstall: pandas
#    -------------------------------- ------- 32/39 [scikit-learn]
#     Found existing installation: pandas 2.2.3
#    -------------------------------- ------- 32/39 [scikit-learn]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#     Uninstalling pandas-2.2.3:
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#       Successfully uninstalled pandas-2.2.3
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#    --------------------------------- ------ 33/39 [pandas]
#   Attempting uninstall: aiohttp
#    --------------------------------- ------ 33/39 [pandas]
#     Found existing installation: aiohttp 3.11.10
#    --------------------------------- ------ 33/39 [pandas]
#     Uninstalling aiohttp-3.11.10:
#    --------------------------------- ------ 33/39 [pandas]
#       Successfully uninstalled aiohttp-3.11.10
#    --------------------------------- ------ 33/39 [pandas]
#    ---------------------------------- ----- 34/39 [aiohttp]
#    ---------------------------------- ----- 34/39 [aiohttp]
#    ---------------------------------- ----- 34/39 [aiohttp]
#    ---------------------------------- ----- 34/39 [aiohttp]
#    ---------------------------------- ----- 34/39 [aiohttp]
#   Attempting uninstall: torchmetrics
#    ---------------------------------- ----- 34/39 [aiohttp]
#     Found existing installation: torchmetrics 1.8.0
#    ---------------------------------- ----- 34/39 [aiohttp]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#     Uninstalling torchmetrics-1.8.0:
#    ----------------------------------- ---- 35/39 [torchmetrics]
#       Successfully uninstalled torchmetrics-1.8.0
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ----------------------------------- ---- 35/39 [torchmetrics]
#   Attempting uninstall: pytorch-lightning
#    ----------------------------------- ---- 35/39 [torchmetrics]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#     Found existing installation: pytorch-lightning 2.5.2
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#     Uninstalling pytorch-lightning-2.5.2:
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#       Successfully uninstalled pytorch-lightning-2.5.2
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#   Attempting uninstall: lightning
#    ------------------------------------ --- 36/39 [pytorch-lightning]
#    ------------------------------------- -- 37/39 [lightning]
#     Found existing installation: lightning 2.5.2
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#     Uninstalling lightning-2.5.2:
#    ------------------------------------- -- 37/39 [lightning]
#       Successfully uninstalled lightning-2.5.2
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#    ------------------------------------- -- 37/39 [lightning]
#   Attempting uninstall: pytorch-forecasting
#    ------------------------------------- -- 37/39 [lightning]
#     Found existing installation: pytorch-forecasting 1.4.0
#    ------------------------------------- -- 37/39 [lightning]
#    -------------------------------------- - 38/39 [pytorch-forecasting]
#     Uninstalling pytorch-forecasting-1.4.0:
#    -------------------------------------- - 38/39 [pytorch-forecasting]
#       Successfully uninstalled pytorch-forecasting-1.4.0
#    -------------------------------------- - 38/39 [pytorch-forecasting]
#    -------------------------------------- - 38/39 [pytorch-forecasting]
#    -------------------------------------- - 38/39 [pytorch-forecasting]
#    -------------------------------------- - 38/39 [pytorch-forecasting]
#    -------------------------------------- - 38/39 [pytorch-forecasting]
#    -------------------------------------- - 38/39 [pytorch-forecasting]
#    ---------------------------------------- 39/39 [pytorch-forecasting]
#
# Successfully installed MarkupSafe-3.0.2 PyYAML-6.0.2 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 attrs-25.3.0 colorama-0.4.6 filelock-3.18.0 frozenlist-1.7.0 fsspec-2025.7.0 idna-3.10 jinja2-3.1.6 joblib-1.5.1 lightning-2.5.2 lightning-utilities-0.15.0 mpmath-1.3.0 multidict-6.6.3 networkx-3.5 numpy-2.3.2 packaging-25.0 pandas-2.3.1 propcache-0.3.2 python-dateutil-2.9.0.post0 pytorch-forecasting-1.4.0 pytorch-lightning-2.5.2 pytz-2025.2 scikit-base-0.12.4 scikit-learn-1.7.1 scipy-1.16.1 setuptools-80.9.0 six-1.17.0 sympy-1.14.0 threadpoolctl-3.6.0 torch-2.7.1 torchmetrics-1.8.0 tqdm-4.67.1 typing-extensions-4.14.1 tzdata-2025.2 yarl-1.20.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\frang\anaconda3\Lib\site-packages\~orch'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 2.3.2 which is incompatible.
# s3fs 2025.3.2 requires fsspec==2025.3.2.*, but you have fsspec 2025.7.0 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.1 which is incompatible.
# streamlit 1.45.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.

# %%
# !pip install pytorch_forecasting --upgrade

import pandas as pd
import numpy as np
from pathlib import Path
import torch
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import joblib

from pytorch_forecasting import TimeSeriesDataSet, TemporalFusionTransformer
from pytorch_forecasting.metrics import RMSE
from pytorch_forecasting.data import NaNLabelEncoder
from pytorch_lightning import Trainer
import pytorch_lightning as pl
# Out:
# Requirement already satisfied: pytorch_forecasting in c:\users\frang\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy<=3.0.0 in c:\users\frang\anaconda3\lib\site-packages (from pytorch_forecasting) (2.1.3)
# Requirement already satisfied: torch!=2.0.1,<3.0.0,>=2.0.0 in c:\users\frang\anaconda3\lib\site-packages (from pytorch_forecasting) (2.7.1)
# Requirement already satisfied: lightning<3.0.0,>=2.0.0 in c:\users\frang\anaconda3\lib\site-packages (from pytorch_forecasting) (2.5.2)
# Requirement already satisfied: scipy<2.0,>=1.8 in c:\users\frang\anaconda3\lib\site-packages (from pytorch_forecasting) (1.15.3)
# Requirement already satisfied: pandas<3.0.0,>=1.3.0 in c:\users\frang\anaconda3\lib\site-packages (from pytorch_forecasting) (2.2.3)
# Requirement already satisfied: scikit-learn<2.0,>=1.2 in c:\users\frang\anaconda3\lib\site-packages (from pytorch_forecasting) (1.6.1)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in c:\users\frang\anaconda3\lib\site-packages (from lightning<3.0.0,>=2.0.0->pytorch_forecasting) (6.0.2)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in c:\users\frang\anaconda3\lib\site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch_forecasting) (2025.3.2)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\frang\anaconda3\lib\site-packages (from lightning<3.0.0,>=2.0.0->pytorch_forecasting) (0.15.0)
# Requirement already satisfied: packaging<27.0,>=20.0 in c:\users\frang\anaconda3\lib\site-packages (from lightning<3.0.0,>=2.0.0->pytorch_forecasting) (24.2)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in c:\users\frang\anaconda3\lib\site-packages (from lightning<3.0.0,>=2.0.0->pytorch_forecasting) (1.8.0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in c:\users\frang\anaconda3\lib\site-packages (from lightning<3.0.0,>=2.0.0->pytorch_forecasting) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in c:\users\frang\anaconda3\lib\site-packages (from lightning<3.0.0,>=2.0.0->pytorch_forecasting) (4.12.2)
# Requirement already satisfied: pytorch-lightning in c:\users\frang\anaconda3\lib\site-packages (from lightning<3.0.0,>=2.0.0->pytorch_forecasting) (2.5.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\frang\anaconda3\lib\site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch_forecasting) (3.11.10)
# Requirement already satisfied: setuptools in c:\users\frang\anaconda3\lib\site-packages (from lightning-utilities<2.0,>=0.10.0->lightning<3.0.0,>=2.0.0->pytorch_forecasting) (72.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\frang\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.3.0->pytorch_forecasting) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\frang\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.3.0->pytorch_forecasting) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\frang\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.3.0->pytorch_forecasting) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\frang\anaconda3\lib\site-packages (from scikit-learn<2.0,>=1.2->pytorch_forecasting) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\frang\anaconda3\lib\site-packages (from scikit-learn<2.0,>=1.2->pytorch_forecasting) (3.5.0)
# Requirement already satisfied: filelock in c:\users\frang\anaconda3\lib\site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch_forecasting) (3.17.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\frang\anaconda3\lib\site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch_forecasting) (1.13.3)
# Requirement already satisfied: networkx in c:\users\frang\anaconda3\lib\site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch_forecasting) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\frang\anaconda3\lib\site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch_forecasting) (3.1.6)
# Requirement already satisfied: colorama in c:\users\frang\anaconda3\lib\site-packages (from tqdm<6.0,>=4.57.0->lightning<3.0.0,>=2.0.0->pytorch_forecasting) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\frang\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch_forecasting) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\frang\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch_forecasting) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\frang\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch_forecasting) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\frang\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch_forecasting) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\frang\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch_forecasting) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\frang\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch_forecasting) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\frang\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch_forecasting) (1.18.0)
# Requirement already satisfied: idna>=2.0 in c:\users\frang\anaconda3\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch_forecasting) (3.7)
# Requirement already satisfied: six>=1.5 in c:\users\frang\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.3.0->pytorch_forecasting) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\frang\anaconda3\lib\site-packages (from sympy>=1.13.3->torch!=2.0.1,<3.0.0,>=2.0.0->pytorch_forecasting) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\frang\anaconda3\lib\site-packages (from jinja2->torch!=2.0.1,<3.0.0,>=2.0.0->pytorch_forecasting) (3.0.2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 12
#       9 import matplotlib.pyplot as plt
#      10 import joblib
# ---> 12 from pytorch_forecasting import TimeSeriesDataSet, TemporalFusionTransformer
#      13 from pytorch_forecasting.metrics import RMSE
#      14 from pytorch_forecasting.data import NaNLabelEncoder
#
# File ~\anaconda3\Lib\site-packages\pytorch_forecasting\__init__.py:34
#       7 from pytorch_forecasting.data import (
#       8     EncoderNormalizer,
#       9     GroupNormalizer,
#    (...)
#      12     TimeSeriesDataSet,
#      13 )
#      14 from pytorch_forecasting.metrics import (
#      15     MAE,
#      16     MAPE,
#    (...)
#      32     QuantileLoss,
#      33 )
# ---> 34 from pytorch_forecasting.models import (
#      35     GRU,
#      36     LSTM,
#      37     AutoRegressiveBaseModel,
#      38     AutoRegressiveBaseModelWithCovariates,
#      39     Baseline,
#      40     BaseModel,
#      41     BaseModelWithCovariates,
#      42     DecoderMLP,
#      43     DeepAR,
#      44     MultiEmbedding,
#      45     NBeats,
#      46     NHiTS,
#      47     RecurrentNetwork,
#      48     TemporalFusionTransformer,
#      49     TiDEModel,
#      50     get_rnn,
#      51 )
#      52 from pytorch_forecasting.utils import (
#      53     apply_to_list,
#      54     autocorrelation,
#    (...)
#      63     unpack_sequence,
#      64 )
#      65 from pytorch_forecasting.utils._maint._show_versions import show_versions
#
# File ~\anaconda3\Lib\site-packages\pytorch_forecasting\models\__init__.py:5
#       1 """
#       2 Models for timeseries forecasting.
#       3 """
# ----> 5 from pytorch_forecasting.models.base import (
#       6     AutoRegressiveBaseModel,
#       7     AutoRegressiveBaseModelWithCovariates,
#       8     BaseModel,
#       9     BaseModelWithCovariates,
#      10 )
#      11 from pytorch_forecasting.models.baseline import Baseline
#      12 from pytorch_forecasting.models.deepar import DeepAR
#
# File ~\anaconda3\Lib\site-packages\pytorch_forecasting\models\base\__init__.py:10
#       1 """Base classes for pytorch-foercasting models."""
#       3 from pytorch_forecasting.models.base._base_model import (
#       4     AutoRegressiveBaseModel,
#       5     AutoRegressiveBaseModelWithCovariates,
#    (...)
#       8     Prediction,
#       9 )
# ---> 10 from pytorch_forecasting.models.base._base_object import (
#      11     _BaseObject,
#      12     _BasePtForecaster,
#      13 )
#      15 __all__ = [
#      16     "_BaseObject",
#      17     "_BasePtForecaster",
#    (...)
#      22     "Prediction",
#      23 ]
#
# File ~\anaconda3\Lib\site-packages\pytorch_forecasting\models\base\_base_object.py:7
#       3 import inspect
#       5 from pytorch_forecasting.utils._dependencies import _safe_import
# ----> 7 _SkbaseBaseObject = _safe_import("skbase.base.BaseObject", pkg_name="scikit-base")
#      10 class _BaseObject(_SkbaseBaseObject):
#      11     pass
#
# File ~\anaconda3\Lib\site-packages\pytorch_forecasting\utils\_dependencies\_safe_import.py:82, in _safe_import(import_path, pkg_name)
#      79     pkg_name = path_list[0]
#      80 obj_name = path_list[-1]
# ---> 82 if pkg_name in _get_installed_packages():
#      83     try:
#      84         if len(path_list) == 1:
#
# File ~\anaconda3\Lib\site-packages\pytorch_forecasting\utils\_dependencies\_dependencies.py:40, in _get_installed_packages()
#      31 def _get_installed_packages():
#      32     """Get a dictionary of installed packages and their versions.
#      33
#      34     Returns
#    (...)
#      38         MAJOR.MINOR.PATCH version format is used for versions, e.g., "1.2.3"
#      39     """
# ---> 40     return _get_installed_packages_private().copy()
#
# File ~\anaconda3\Lib\site-packages\pytorch_forecasting\utils\_dependencies\_dependencies.py:20, in _get_installed_packages_private()
#      18 dists = distributions()
#      19 package_names = {dist.metadata["Name"] for dist in dists}
# ---> 20 package_versions = {pkg_name: version(pkg_name) for pkg_name in package_names}
#      21 # developer note:
#      22 # we cannot just use distributions naively,
#      23 # because the same top level package name may appear *twice*,
#    (...)
#      26 # the "version" contract ensures we always get the version that corresponds
#      27 # to the importable distribution, i.e., the top one in the sys.path.
#      28 return package_versions
#
# File ~\anaconda3\Lib\importlib\metadata\__init__.py:987, in version(distribution_name)
#     980 def version(distribution_name: str) -> str:
#     981     """Get the version string for the named package.
#     982
#     983     :param distribution_name: The name of the distribution package to query.
#     984     :return: The version string for the package as defined in the package's
#     985         "Version" metadata key.
#     986     """
# --> 987     return distribution(distribution_name).version
#
# File ~\anaconda3\Lib\importlib\metadata\__init__.py:960, in distribution(distribution_name)
#     954 def distribution(distribution_name: str) -> Distribution:
#     955     """Get the ``Distribution`` instance for the named package.
#     956
#     957     :param distribution_name: The name of the distribution package as a string.
#     958     :return: A ``Distribution`` instance (or subclass thereof).
#     959     """
# --> 960     return Distribution.from_name(distribution_name)
#
# File ~\anaconda3\Lib\importlib\metadata\__init__.py:405, in Distribution.from_name(cls, name)
#     395 """Return the Distribution for the given package name.
#     396
#     397 :param name: The name of the distribution package to search for.
#    (...)
#     402 :raises ValueError: When an invalid value is supplied for name.
#     403 """
#     404 if not name:
# --> 405     raise ValueError("A distribution name is required.")
#     406 try:
#     407     return next(iter(cls.discover(name=name)))
#
# ValueError: A distribution name is required.

# %%
# Paths
FEATURES_DATA_DIR = Path("../data/processed")
MODELS_DIR = Path("../models")
MODELS_DIR.mkdir(exist_ok=True)

# Parameters
MAX_ENCODER_LENGTH = 30  # history length
MAX_PREDICTION_LENGTH = 1  # forecast horizon (1 day ahead)
EPOCHS = 50
BATCH_SIZE = 32
ACCELERATOR = "gpu" if torch.cuda.is_available() else "cpu"

pl.seed_everything(42)

# %%
# Loop over all assets
for feature_file in FEATURES_DATA_DIR.glob("*_features.csv"):
    asset_name = feature_file.stem.replace("_features", "")
    print(f"\n=== Training TFT for {asset_name} ===")

    # Load and prepare data
    df = pd.read_csv(feature_file).sort_values("Date").dropna()

    # Keep needed features
    feature_cols = [
        "Return", "Volatility_5d", "Volatility_21d",
        "RSI_14", "MACD", "MACD_signal", "MACD_hist",
        "ATR_14", "SMA_20", "SMA_50", "SMA_200"
    ]
    target_col = "Volatility_5d"

    # Scaling
    scaler_X = StandardScaler()
    df[feature_cols] = scaler_X.fit_transform(df[feature_cols])
    scaler_y = StandardScaler()
    df[target_col] = scaler_y.fit_transform(df[[target_col]])

    # Save scalers
    joblib.dump(scaler_X, MODELS_DIR / f"scaler_X_TFT_{asset_name}.pkl")
    joblib.dump(scaler_y, MODELS_DIR / f"scaler_y_TFT_{asset_name}.pkl")

    # Add time index and group id for TFT
    df["time_idx"] = np.arange(len(df))
    df["asset"] = asset_name

    # Train/test split index
    split_idx = int(len(df) * 0.8)

    # Define TimeSeriesDataSet
    training = TimeSeriesDataSet(
        df.iloc[:split_idx],
        time_idx="time_idx",
        target=target_col,
        group_ids=["asset"],
        min_encoder_length=MAX_ENCODER_LENGTH,
        max_encoder_length=MAX_ENCODER_LENGTH,
        max_prediction_length=MAX_PREDICTION_LENGTH,
        time_varying_known_reals=feature_cols,
        time_varying_unknown_reals=[target_col],
        target_normalizer=None
    )

    validation = TimeSeriesDataSet.from_dataset(training, df.iloc[split_idx:])

    train_dataloader = training.to_dataloader(train=True, batch_size=BATCH_SIZE, num_workers=0)
    val_dataloader = validation.to_dataloader(train=False, batch_size=BATCH_SIZE, num_workers=0)

    # Create TFT model
    tft = TemporalFusionTransformer.from_dataset(
        training,
        learning_rate=1e-3,
        hidden_size=32,
        attention_head_size=4,
        dropout=0.1,
        hidden_continuous_size=16,
        output_size=1,  # 1 target
        loss=RMSE(),
        log_interval=10,
        reduce_on_plateau_patience=4
    )

    trainer = Trainer(
        max_epochs=EPOCHS,
        accelerator=ACCELERATOR,
        devices=1,
        gradient_clip_val=0.1
    )

    # Train model
    trainer.fit(tft, train_dataloaders=train_dataloader, val_dataloaders=val_dataloader)

    # Save model
    tft_path = MODELS_DIR / f"volatility_model_tft_{asset_name}.ckpt"
    trainer.save_checkpoint(str(tft_path))

    # Predictions
    raw_predictions, x = tft.predict(val_dataloader, mode="raw", return_x=True)
    preds = tft.predict(val_dataloader).numpy().flatten()

    # Inverse scaling
    preds = scaler_y.inverse_transform(preds.reshape(-1, 1)).flatten()
    actuals = scaler_y.inverse_transform(x["decoder_target"].numpy().flatten().reshape(-1, 1)).flatten()

    # Metrics
    rmse = np.sqrt(mean_squared_error(actuals, preds))
    mae = mean_absolute_error(actuals, preds)
    print(f"{asset_name} → RMSE: {rmse:.6f}, MAE: {mae:.6f}")

    # Save predictions CSV
    pred_df = pd.DataFrame({
        "Date": df["Date"].iloc[split_idx + MAX_ENCODER_LENGTH:].values[:len(preds)],
        "Actual_Volatility": actuals[:len(preds)],
        "Predicted_Volatility": preds[:len(preds)]
    })
    pred_df.to_csv(MODELS_DIR / f"predictions_TFT_{asset_name}.csv", index=False)

    # Plot
    plt.figure(figsize=(12, 5))
    plt.plot(actuals, label="Actual Volatility")
    plt.plot(preds, label="Predicted Volatility")
    plt.title(f"TFT Volatility Prediction - {asset_name}")
    plt.legend()
    plt.show()
